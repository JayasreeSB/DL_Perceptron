# %%
#CH.SC.U4AIE24028

import numpy as np

class SinglePerceptron:
    def __init__(self, input_size, lr=0.1, epochs=20):
        self.weights = np.zeros(input_size + 1)
        self.lr = lr
        self.epochs = epochs

    def activation(self, x):
        return 1 if x >= 0 else 0

    def predict(self, x):
        z = np.dot(x, self.weights[1:]) + self.weights[0]
        return self.activation(z)

    def train(self, X, y):
        for _ in range(self.epochs):
            for xi, target in zip(X, y):
                prediction = self.predict(xi)
                error = target - prediction
                self.weights[1:] += self.lr * error * xi
                self.weights[0] += self.lr * error

X_and = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y_and = np.array([0, 0, 0, 1])

perceptron = SinglePerceptron(input_size=2)
perceptron.train(X_and, y_and)

user_in = input("Enter two binary inputs separated by space (e.g., 1 1): ")
x1, x2 = map(int, user_in.split())
result = perceptron.predict(np.array([x1, x2]))
print(f"Output: {result}")
# Out:
# Enter two binary inputs separated by space (e.g., 1 1): 1 1
# Output: 1

# %%
#CH.SC.U4AIE24028

import numpy as np
import tensorflow as tf
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

X_xor = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_xor = np.array([[0], [1], [1], [0]], dtype=np.float32)

mlp_model = tf.keras.Sequential([
    tf.keras.layers.Dense(4, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

mlp_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

mlp_model.fit(X_xor, y_xor, epochs=200, verbose=0)

user_in = input("Enter two binary inputs separated by space (e.g., 1 0): ")
# Instead of input(), just hardcode the test values
x1, x2 = 1.0, 0.0
pred = mlp_model.predict(np.array([[x1, x2]]), verbose=0)
print(f"Output: {int(np.round(pred[0][0]))}")
# Out:
# Enter two binary inputs separated by space (e.g., 1 0): 1 0
# Output: 1

# %%
#CH.SC.U4AIE24028

import numpy as np
import tensorflow as tf
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

mnist = tf.keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train, X_test = X_train / 255.0, X_test / 255.0

mnist_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

mnist_model.compile(optimizer='adam',
                    loss='sparse_categorical_crossentropy',
                    metrics=['accuracy'])

print("Training model... Please wait.")
mnist_model.fit(X_train, y_train, epochs=3, batch_size=32, verbose=0)

user_in = input("Enter a test image index (0 to 9999): ")
idx = int(user_in)
img = X_test[idx]

pred = mnist_model.predict(np.array([img]), verbose=0)
print(f"Actual Label: {y_test[idx]}")
print(f"Predicted Output: {np.argmax(pred)}")
# Out:
# Training model... Please wait.
# Enter a test image index (0 to 9999): 899
# Actual Label: 8
# Predicted Output: 8
